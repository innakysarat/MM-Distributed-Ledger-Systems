# %% [markdown]
# # Home Assignment 5

# %% [markdown]
# ## Problem 1 (3 points). Shamir secret sharing

# %% [markdown]
# Find the secret and initial polynomial in (n, 4)-threshold Shamir secret sharing scheme over $F_{19}$ for $(3,17); (17,5); (5,11); (11,4)$. Is it consistent with $(4, 3)$?

# %% [markdown]
# **Given**:
#
# $F(3) = 17$, $F(5) = 11$, $F(11) = 4$, $F(17) = 5$, $p = 19$
#
# $Secret = F(0) = ?$
#
# **Solution**:
#
# $F(x) = \sum_{i=1}^{4} y_{i} \times l_{x_{i}}(x)$
#
# $l_{x_{i}} = \prod_{i \neq j} \frac{x - x_{j}}{x_{i} - x_{j}}$
#
# $F(x) = 17\frac {(x - 5)(x - 11)(x - 17)} {(3 - 5)(3 - 11)(3 - 17)} + 11\frac {(x - 3)(x - 11)(x - 17)} {(5 - 3)(5 - 11)(5 - 17)} + 4\frac {(x - 3)(x - 5)(x - 17)} {(11 - 3)(11 - 5) (11 - 17)} + 5\frac {(x - 3)(x - 5)(x - 11)}{(17 - 3)(17 - 5)(17 - 11)} = 17 \frac {(x - 5)(x - 11)(x - 17)} {-224} + 11 \frac {(x - 3)(x - 11)(x - 17)} {144} + 4 \frac {(x - 3)(x - 5)(x - 17)} {-288} + 5 \frac {(x - 3)(x - 5)(x - 11)} {1008} = - 17*(x - 5)(x - 11)(x - 17)*224^{-1} + 11*(x - 3)(x - 11)(x - 17)*144^{-1} - 4*(x - 3)(x - 5)(x - 17)*288^{-1} + 5*(x - 3)(x - 5)(x - 11)*1008^{-1} = 9(x - 5)(x - 11)(x - 17) + (x - 3)(x - 11)(x - 17) + 5(x - 3)(x - 5)(x - 17) + 5(x - 3)(x - 5)(x - 11) = 20x^3 - 548x^2 + 4484x - 11076 = x^3 + 3x^2 + 1$
#
# **Initial polynomial**:
# $x^3 +3x^2 + 1$
#
# **Secret**: $F(0) = 1$
#
# $F(4) = 4^3 + 3*4^2 + 1 = 7 + 10 + 1 = 18$
#
# $18 \neq 3 \therefore$ polynomial is not consistent with $(4,3)$

# %% [markdown]
# ## Problem 2 (2* points). Schnorr ring signature

# %% [markdown]
# For the elliptic curve $y^2=x^3+7$ over $F_{127}$ and the hash function $H() = SHA256()\%127$. Consider a subgroup of point on a curve with a generator $G = (19, 32)$.
#
# Suppose Alice has a private key $a = 17$ and Bob has a private key $b = 29$.
#
# 1. (0 points) Compute public keys.
# 2. (2* points) Generate Schnorr's ring signature for $m=77$ on Alice's behalf with $k=101$.

# %% [markdown]
# 1. Public key: P = aG
#
# $P_{A} = 17 * (19, 32)$
# $P_{B} = 29 * (19, 32)$

# %% [markdown]
# ## Problem 3 (3 points). Bitcoin data

# %% [markdown]
# Consider tx=21e8fd77b81b6c4cf6723c10ea83acae77728f188ee6f4cd97ae114665b5fc0f (block height: 478994, tx index/position: 1603). Trace the transaction back to address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw.
#
# Use blockexplorer Python library, Bitcoin RPC or their equivalent alternative.

# %%
import requests, json

tx = "21e8fd77b81b6c4cf6723c10ea83acae77728f188ee6f4cd97ae114665b5fc0f"
base_url = "https://blockchain.info/"
tx = requests.get(base_url + "rawtx/" + tx)
tx = json.loads(tx.text)

txs_step_1 = []
txs_step_2 = []
txs_step_3 = []

def iterate(txs_step_i, step):
    for input_addr in tx["inputs"]:
        prev_tx = requests.get(base_url + "rawtx/" + str(input_addr["prev_out"]["tx_index"]))
        prev_tx = json.loads(prev_tx.text)
        txs_step_i.append(prev_tx)
        for output in prev_tx["out"]:
            if output["addr"] == "12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw":
                if (step == 1 | step == 2):
                    print(f"Transaction {tx.tx_index} spent {output.value/1e8} BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw")
                    break
                if step == 3:
                    print("Found transaction with hash " + str(prev_tx["hash"]) + " that spends " + str(output["value"]/1e8) + " BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw")  
                    break

iterate(txs_step_1, 1)
            
for tx in txs_step_1:
    iterate(txs_step_2, 2)

for tx in txs_step_2:
    iterate(txs_step_3, 3)
# Out:
# Found transaction with hash 00a612aa7b2e35de0be7025b77c3934a4428fe951b34236701fdd48466f62992 that spends 0.17124673 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 02b43152862ee98f00954eaf2cad6ecf8d6fe09dffb9f35be445dd8b10448f34 that spends 0.1801023 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 04cc3f8cc717d27425359a61dbd527a4d29f34c1b13d4d189bfc00e6661ae808 that spends 0.16656716 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 055a69935824db79df6fd42496c6a35f5f291add5196b306bf0a927b334584d8 that spends 0.1703 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 0955b755d72821c9b1cfc9e7673710806244c56ab955c6c28c5630013846563b that spends 0.169 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 0a9d3c83d6d380616bac17c687ed8e5a2bd48d761264753fae3fecf8bb264a03 that spends 0.1804 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 0c5479ba07223358ee6da10b6be9220aa5b844d0d2cfbdc82ffe60a8bd89727d that spends 0.17887884 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 19bcc901b504eda67cb7938ebe636805b2e5432952a6043ddd8e137059d44a42 that spends 0.336 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 1a62892b7ec8af5d83eef722968a8bb30152f07f4b56fdd21e5c1bc79b04a391 that spends 0.32 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 2099a55c68e1b88d03ba342fddf393c336f1c7d8ec819e5fc0a14a9ea13a6a5f that spends 0.1486 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 251682e9694247ad5f75ca243cfa0f98b5a5132ab1725b0f06304023c8f802d0 that spends 0.36 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 2a63dec74e289a10278d43a397c638a2939880030ecff12fd711c0285079498d that spends 0.174002 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 2bccc8d2b72da8c8733aef73a7bad85ae3bf834f86607540a68b4a8ef252e32c that spends 0.16894486 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 3a2880216a32aa5a8a88aaaaeaf33720a7da22d57cd9182a1f95380ebdf94df7 that spends 0.171 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 42079398d4a0f0e646391fad5e9fa008c0efc81191a8eb9c3de4636745805fff that spends 0.17937739 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 49c91fe410a59a3ecd14143eaf0e13df5853b742837114fdc2242f4bd32140cb that spends 0.18403892 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 4acc1957262744cd607b3737cb80f2d3ab25147dd2d2eb661bdaabd26faa3c6d that spends 0.16144753 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 51e4c4fc2f438b0ed09c6e5d506423c044ce110ff26c4b3fb341d39ca74cffc2 that spends 0.1719 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 54cfb90ff776c2478983ce74e58b17b69eda2ed006c161cbf146756975da16fd that spends 0.15500051 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 577bbad2c44de9511c6ec1d6bfc60902a656d3448bd125ca1f4f6842642959d7 that spends 0.16539325 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 637e00635c3840b928a1dae318b7a3c672921bb938218ce6830623119789b620 that spends 0.1715 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 69f5a76a65ff25a06e8137546f5a1269ebcfdf6577604eead43baddf86aba9e8 that spends 0.17354205 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 70b5fa489c8671a62583520c1da34d8b4f9133497a92c0ef1e3c5a761d7723a6 that spends 0.16722501 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 7931034c07ed5a3ea630450baa8dd48cf1fcfe071b246fe75f3d2cdd32d7ef85 that spends 0.1801648 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 7ecc79722c3f6ef39101418b26b884de8456ee061ef3e9cced116dca036e37b7 that spends 0.17343234 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 949f0c480e3109e75eac4c22ad17d07557050fc7efcfcedb6a14b4c370d90842 that spends 0.182761 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash 9f09cea9e024dc649ba0d200dacfd9af40492a6bf438ff10396366c88b1baf3f that spends 0.176 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash aaa76683d8795fcfac068eb8e9d547bf3f5eb5cbfd96d030276797f493b72a89 that spends 0.16321544 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash b28971e13e9ec2b93fe8e2bf12bf2e22b90dbb0e8dd9fbb82131263f86300957 that spends 0.25321436 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash b759b0670b0369d84580c051da440fb97e8f602ffc3425c98b3f0aefeccecaec that spends 0.19 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash cdadee896e757a1e0664cf98e5647b59b484f7f28ff86bdce4ab5e3c5da5eb00 that spends 0.17345057 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash d10d5ac43cf64dbf2fb9799cf6cf6e52069876243dfd2467f3ef3094c509f968 that spends 0.178 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash eb77bfaef115a15fcfe277627e5f7ae6e416bb192403fdc90447996b49b5c651 that spends 1.999 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash f175e479f74bff3f33dde7c6aa41723d20fba414127cd88543a1f4002b73d88b that spends 0.300404 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash f37bf1e3f25816d5ff077e9c784c7e7b05c5639e2b1af01cbc85ac6a3c2d8fd9 that spends 0.1822893 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw
# Found transaction with hash facc1eaa47414ef5937d38c2d45a5eaa58f148eb287806c75d60d7ab469307de that spends 0.156218 BTC from address 12t9YDPgwueZ9NyMgw519p7AA8isjr6SMw

# %% [markdown]
# ## Problem 4 (3* points). Shared send untangling

# %% [markdown]
# 1. (1* point) Simplify transaction (see Section 1 \[1\])
# * 409803bb5e124fd028c0482027c7722e84ce55b78204b279d3a44aba5e7c1698
# * 9ea6fdad2ea5870f5b17cb28587263f90cd7ec5c67f35d395a318186e5c79333
# * c38aac9910f327700e0f199972eed8ea7c6b1920e965f9cb48a92973e7325046
# * 659135664894e50040830edb516a76f704fd2be409ecd8d1ea9916c002ab28a2
# 2. (2* points) What are these transactions types (see Theorem 1)?
#
# \[1\] https://bitfury.com/content/downloads/bitfury_whitepaper_shared_send_untangling_in_bitcoin_8_24_2016.pdf

# %% [markdown]
# ## Problem 5 (4 points). ERC20 data

# %% [markdown]
# Consider (scam?) token 0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0 from Ethereum mainnet. How many tokens where transfered in Dec-2020?

# %%
import pandas as pd
data = pd.read_csv('Scam token dec-2020.csv')
data = data[data.Method == "Transfer"]
data
# Out:
#                                                  Txhash   Blockno  \
# 4     0x4cefffbfea31bda18eb20c77ad622e18333c50ed3084...  11461644
# 5     0x3bd89b7fd0acf9df3743b8bfe12c75f51173265d1e90...  11461677
# 6     0x5b1909ab79b6513aefcef1bd530e74d30be5bf6ddfd2...  11461710
# 7     0xffe4322c3bdc48efa2b3332df04e31cb39d17200d957...  11461718
# 8     0x7735c24a0a7584cb94a679de4cb8ef864c777a955867...  11461758
# ...                                                 ...       ...
# 2261  0x7a18e80993465fa9898c7cded940ee468aa63a9f6ec9...  11556561
# 2266  0x1cf778fb2778b3ab9bc8a160e4518a93c73da9256a4e...  11558996
# 2267  0xab9daab3a2e67b006abf480c5649a58f4dc06295e478...  11559000
# 2272  0xfba9c1dd6042654388f65e388af24bb2ab05af00b663...  11561630
# 2275  0xa8e7056a26899c372387f356788fe33eabbe88daabd2...  11563649
#
#       UnixTimestamp             DateTime  \
# 4        1608088590  2020-12-16 03:16:30
# 5        1608089180  2020-12-16 03:26:20
# 6        1608089519  2020-12-16 03:31:59
# 7        1608089696  2020-12-16 03:34:56
# 8        1608090107  2020-12-16 03:41:47
# ...             ...                  ...
# 2261     1609346669  2020-12-30 16:44:29
# 2266     1609378817  2020-12-31 01:40:17
# 2267     1609378868  2020-12-31 01:41:08
# 2272     1609413763  2020-12-31 11:22:43
# 2275     1609440685  2020-12-31 18:51:25
#
#                                             From  \
# 4     0x4775259e2cb64ad5bda0a396568732fc655c593c
# 5     0xaf9981d21d212d9cb5f2c9df6b56029737ac53e7
# 6     0xaf9981d21d212d9cb5f2c9df6b56029737ac53e7
# 7     0x1bfeaf74553325fc7064f6d19287cb9374ce3f05
# 8     0x3e9afaa4a062a49d64b8ab057b3cb51892e17ecb
# ...                                          ...
# 2261  0x6f3730a184054b96786dda5387ea70a9967732d1
# 2266  0x4e0e8e636d01216855946aaa163d7fb73c86d070
# 2267  0x3e9afaa4a062a49d64b8ab057b3cb51892e17ecb
# 2272  0x141fef8cd8397a390afe94846c8bd6f4ab981c48
# 2275  0x6f3730a184054b96786dda5387ea70a9967732d1
#
#                                               To  ContractAddress  \
# 4     0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 5     0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 6     0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 7     0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 8     0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# ...                                          ...              ...
# 2261  0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 2266  0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 2267  0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 2272  0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 2275  0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
#
#       Value_IN(ETH)  Value_OUT(ETH)  CurrentValue @ $1689.35/Eth  TxnFee(ETH)  \
# 4               0.0               0                          0.0     0.003797
# 5               0.0               0                          0.0     0.003873
# 6               0.0               0                          0.0     0.001699
# 7               0.0               0                          0.0     0.003450
# 8               0.0               0                          0.0     0.004413
# ...             ...             ...                          ...          ...
# 2261            0.0               0                          0.0     0.002519
# 2266            0.0               0                          0.0     0.002154
# 2267            0.0               0                          0.0     0.005184
# 2272            0.0               0                          0.0     0.003894
# 2275            0.0               0                          0.0     0.001217
#
#       TxnFee(USD)  Historical $Price/Eth Status ErrCode    Method  Unnamed: 16
# 4        6.414611                 637.74    NaN     NaN  Transfer          NaN
# 5        6.543106                 637.74    NaN     NaN  Transfer          NaN
# 6        2.869648                 637.74    NaN     NaN  Transfer          NaN
# 7        5.827649                 637.74    NaN     NaN  Transfer          NaN
# 8        7.454818                 637.74    NaN     NaN  Transfer          NaN
# ...           ...                    ...    ...     ...       ...          ...
# 2261     4.255581                 752.53    NaN     NaN  Transfer          NaN
# 2266     3.638394                 737.15    NaN     NaN  Transfer          NaN
# 2267     8.757124                 737.15    NaN     NaN  Transfer          NaN
# 2272     6.579109                 737.15    NaN     NaN  Transfer          NaN
# 2275     2.055662                 737.15    NaN     NaN  Transfer          NaN
#
# [613 rows x 17 columns]

# %%
data.ErrCode.unique()
# Out:
# array([nan, 'Out of gas', 'Reverted'], dtype=object)

# %%
data.Status.unique()
# Out:
# array([nan, 'Error(0)'], dtype=object)

# %%
err_data = data[(data.ErrCode == 'Out of gas') | (data.ErrCode == 'Reverted')]
err_data
# Out:
#                                                  Txhash   Blockno  \
# 917   0xdb9dd43516fb9565bd7e0400f418253cf4b49474e3ea...  11477432
# 1979  0x2ca0fbb1c544f722f3e09dfe2c90752e183bb41e8282...  11498506
# 1991  0x3150184f22143156e6a0eda6aa689a0a9dbf2d96e131...  11498834
# 2004  0x95f703c3643c1b0683d9829ba5d49dd326426c525106...  11499084
# 2075  0xc1294519a0fb8a5332baf23248c91bdeb696ff2b997f...  11504597
#
#       UnixTimestamp             DateTime  \
# 917      1608297605  2020-12-18 13:20:05
# 1979     1608577233  2020-12-21 19:00:33
# 1991     1608581589  2020-12-21 20:13:09
# 2004     1608584798  2020-12-21 21:06:38
# 2075     1608657380  2020-12-22 17:16:20
#
#                                             From  \
# 917   0x36bc2a779283b0581728c1a52b1eeab4e2585b08
# 1979  0x35821c98d3913377dbf90c1703d53d3ea17780ef
# 1991  0x34ef2c22bd8047e72d8cb9f5517e96d0ee026dfd
# 2004  0x54f62de0a9519fc9e98e3e807ac2ecb66d5d2061
# 2075  0x6e3e80d88fd4e3417831b8686db83fc36dbe5fee
#
#                                               To  ContractAddress  \
# 917   0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 1979  0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 1991  0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 2004  0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 2075  0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
#
#       Value_IN(ETH)  Value_OUT(ETH)  CurrentValue @ $1689.35/Eth  TxnFee(ETH)  \
# 917        0.004159               0                     7.026007     0.000924
# 1979       0.000000               0                     0.000000     0.000828
# 1991       0.000000               0                     0.000000     0.003594
# 2004       0.000000               0                     0.000000     0.000827
# 2075       0.000000               0                     0.000000     0.002839
#
#       TxnFee(USD)  Historical $Price/Eth    Status     ErrCode    Method  \
# 917      1.560959                 654.55  Error(0)  Out of gas  Transfer
# 1979     1.398241                 607.90  Error(0)    Reverted  Transfer
# 1991     6.072362                 607.90  Error(0)    Reverted  Transfer
# 2004     1.397532                 607.90  Error(0)    Reverted  Transfer
# 2075     4.796403                 637.23  Error(0)    Reverted  Transfer
#
#       Unnamed: 16
# 917           NaN
# 1979          NaN
# 1991          NaN
# 2004          NaN
# 2075          NaN

# %%
corrected_data = data[data.ErrCode.isna()]
corrected_data
# Out:
#                                                  Txhash   Blockno  \
# 4     0x4cefffbfea31bda18eb20c77ad622e18333c50ed3084...  11461644
# 5     0x3bd89b7fd0acf9df3743b8bfe12c75f51173265d1e90...  11461677
# 6     0x5b1909ab79b6513aefcef1bd530e74d30be5bf6ddfd2...  11461710
# 7     0xffe4322c3bdc48efa2b3332df04e31cb39d17200d957...  11461718
# 8     0x7735c24a0a7584cb94a679de4cb8ef864c777a955867...  11461758
# ...                                                 ...       ...
# 2261  0x7a18e80993465fa9898c7cded940ee468aa63a9f6ec9...  11556561
# 2266  0x1cf778fb2778b3ab9bc8a160e4518a93c73da9256a4e...  11558996
# 2267  0xab9daab3a2e67b006abf480c5649a58f4dc06295e478...  11559000
# 2272  0xfba9c1dd6042654388f65e388af24bb2ab05af00b663...  11561630
# 2275  0xa8e7056a26899c372387f356788fe33eabbe88daabd2...  11563649
#
#       UnixTimestamp             DateTime  \
# 4        1608088590  2020-12-16 03:16:30
# 5        1608089180  2020-12-16 03:26:20
# 6        1608089519  2020-12-16 03:31:59
# 7        1608089696  2020-12-16 03:34:56
# 8        1608090107  2020-12-16 03:41:47
# ...             ...                  ...
# 2261     1609346669  2020-12-30 16:44:29
# 2266     1609378817  2020-12-31 01:40:17
# 2267     1609378868  2020-12-31 01:41:08
# 2272     1609413763  2020-12-31 11:22:43
# 2275     1609440685  2020-12-31 18:51:25
#
#                                             From  \
# 4     0x4775259e2cb64ad5bda0a396568732fc655c593c
# 5     0xaf9981d21d212d9cb5f2c9df6b56029737ac53e7
# 6     0xaf9981d21d212d9cb5f2c9df6b56029737ac53e7
# 7     0x1bfeaf74553325fc7064f6d19287cb9374ce3f05
# 8     0x3e9afaa4a062a49d64b8ab057b3cb51892e17ecb
# ...                                          ...
# 2261  0x6f3730a184054b96786dda5387ea70a9967732d1
# 2266  0x4e0e8e636d01216855946aaa163d7fb73c86d070
# 2267  0x3e9afaa4a062a49d64b8ab057b3cb51892e17ecb
# 2272  0x141fef8cd8397a390afe94846c8bd6f4ab981c48
# 2275  0x6f3730a184054b96786dda5387ea70a9967732d1
#
#                                               To  ContractAddress  \
# 4     0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 5     0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 6     0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 7     0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 8     0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# ...                                          ...              ...
# 2261  0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 2266  0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 2267  0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 2272  0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
# 2275  0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0              NaN
#
#       Value_IN(ETH)  Value_OUT(ETH)  CurrentValue @ $1689.35/Eth  TxnFee(ETH)  \
# 4               0.0               0                          0.0     0.003797
# 5               0.0               0                          0.0     0.003873
# 6               0.0               0                          0.0     0.001699
# 7               0.0               0                          0.0     0.003450
# 8               0.0               0                          0.0     0.004413
# ...             ...             ...                          ...          ...
# 2261            0.0               0                          0.0     0.002519
# 2266            0.0               0                          0.0     0.002154
# 2267            0.0               0                          0.0     0.005184
# 2272            0.0               0                          0.0     0.003894
# 2275            0.0               0                          0.0     0.001217
#
#       TxnFee(USD)  Historical $Price/Eth Status ErrCode    Method  Unnamed: 16
# 4        6.414611                 637.74    NaN     NaN  Transfer          NaN
# 5        6.543106                 637.74    NaN     NaN  Transfer          NaN
# 6        2.869648                 637.74    NaN     NaN  Transfer          NaN
# 7        5.827649                 637.74    NaN     NaN  Transfer          NaN
# 8        7.454818                 637.74    NaN     NaN  Transfer          NaN
# ...           ...                    ...    ...     ...       ...          ...
# 2261     4.255581                 752.53    NaN     NaN  Transfer          NaN
# 2266     3.638394                 737.15    NaN     NaN  Transfer          NaN
# 2267     8.757124                 737.15    NaN     NaN  Transfer          NaN
# 2272     6.579109                 737.15    NaN     NaN  Transfer          NaN
# 2275     2.055662                 737.15    NaN     NaN  Transfer          NaN
#
# [608 rows x 17 columns]

# %%
corrected_data.nunique()
# Out:
# Txhash                         608
# Blockno                        501
# UnixTimestamp                  501
# DateTime                       501
# From                           319
# To                               1
# ContractAddress                  0
# Value_IN(ETH)                    1
# Value_OUT(ETH)                   1
# CurrentValue @ $1689.35/Eth      1
# TxnFee(ETH)                    454
# TxnFee(USD)                    454
# Historical $Price/Eth           15
# Status                           0
# ErrCode                          0
# Method                           1
# Unnamed: 16                      0
# dtype: int64

# %% [markdown]
# 319 различных отправителей суммарно отправили 608 токенов для 0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0 в декабре 2020.

# %% [markdown]
# ## Problem 6 (3* points). BigQuery

# %% [markdown]
# Consider (scam?) token 0xcae72a7a0fd9046cf6b165ca54c9e3a3872109e0 from Ethereum mainnet. Compute the total amount of tokens transfered. Use bigquery-public-data.crypto_ethereum (https://ethereum-etl.readthedocs.io/en/latest/google-bigquery/).
